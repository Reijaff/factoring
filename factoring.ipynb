# %%
import random
import rsa
import math

def profile(func):
    from functools import wraps

    @wraps(func)
    def wrapper(*args, **kwargs):
        from line_profiler import LineProfiler
        prof = LineProfiler()
        try:
            return prof(func)(*args, **kwargs)
        finally:
            prof.print_stats()

    return wrapper

# %%
@profile
def trial_division(n):
    if n % 2 == 0:
        return 2
    else:
        for i in range(3, n, 2):
            if n % i == 0:
                return i


@profile
def random_factoring(n):
    d = 1
    while d == 1:
        x = random.randint(1, n - 1)
        d = math.gcd(x, n)
    if d != n:
        return d


@profile
def rho_random(n):
    d = 1
    while d == 1:
        x = random.randint(1, n - 1)
        y = random.randint(1, n - 1)
        d = math.gcd((x - y) % n, n)
    if d != n:
        return d


@profile
def pollard_rho_classic(n, seed=2, f=lambda x: x**2 + 1):
    x, y, d = seed, seed, 1
    while d == 1:
        y = f(x) % n
        print(x % 137, y % 137)
        d = math.gcd((x - y) % n, n)
        x = y
    if d != n:
        return d


# @profile
def pollard_rho_floyd(n, seed=2, f=lambda x: x**2 + 1):
    x, y, d = seed, seed, 1
    while d == 1:
        x = f(x) % n
        y = f(f(y)) % n
        print(x, y)
        # print(x % 137, y % 137)
        # d = math.gcd((x - y) % n, n)
        if x % 137 == y % 137:
            print(x % 137, y % 137)
            break

    if d != n:
        return d


@profile
def pollard_rho_brent(n, seed=2, f=lambda x: x**2 + 1):
    m = 1000
    y = seed
    r = 1
    q = 1
    d = 1
    while d == 1:
        x = y

        for i in range(r):
            y = f(y) % n

        k = 0

        while k < r and d == 1:
            ys = y
            for i in range(min(m, r - k)):
                y = f(y) % n
                q = q * abs(x - y) % n
            d = math.gcd(q, n)
            k = k + m
        r *= 2

    if d == n:
        while True:
            ys = f(ys) % n
            d = math.gcd(abs(x - ys), n)
            if d > 1:
                break
    return d

# %%
q = rsa.prime.getprime(8)
p = rsa.prime.getprime(8)

# print(math.gcd(q, p))
# print("init primes ", q, p)

n = q * p
# n = 149 * 181 # seed = 7
# n = 455459
# n = 7031
# n = 55
n = 31099
print("prime", n)
print("sqrt prime", math.sqrt(n))

# print(trial_division(n))
# print(random_factoring(n))
# print(rho_random(n))
# print(pollard_rho_classic(n))
# print(pollard_rho_brent(n))
# print(pollard_rho_floyd(n))
print(floyd(f=lambda x: (x**2 + 1)%55, x0=2))
# print(pollard_rho_brent(n))
# print(n / 33)

# while True:
# q = rsa.prime.getprime(8)
# p = rsa.prime.getprime(8)
# n = q * p
# f = pollard_rho_floyd(n)
# if f == None:
# print("prime", n)
# break
# Out:
# prime 31099
# sqrt prime 176.34908562280668
# (6, 2)
